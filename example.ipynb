# %%
from algorithm import *

results = find_scrap_coords('data/example.png', visualize=True)

for res in results:
    print(res)
# Out:
# x center= 509, y center = 506, radius = 474
# x center= 766, y center = 862, radius = 79
# x center= 175, y center = 274, radius = 84
# x center= 823, y center = 186, radius = 53
# (842.6109927807532, 842.7190304925462)
# (723.5827982299583, 928.646687794665)
# (91.3647655945644, 281.81969091127354)
# (153.1317877976232, 192.89647791204237)
# (805.3164605622592, 136.03708942671685)
# (873.288636056579, 202.73478663051813)

# %%
# %%timeit
_ = find_scrap_coords('data/example.png', visualize=False)
# Out:
# 106 ms ± 12.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
